# %%
import pandas as pd

# %% [markdown]
# # Extract: Forbes

# %%
# The path to our CSV file to extract 2017 Forbes_Global_2000 company list
Forbes_2017_csv = "Resources/Forbes_Global_2000_2017.csv"
Forbes_2017_df = pd.read_csv(Forbes_2017_csv)
Forbes_2017_df.head()
# Out:
#                    Company  Market Value  Revenue  Profits    Assets  Rank  \
# 0                     ICBC       229.805  151.381  41.9837  3473.238     1
# 1  China Construction Bank       200.458  134.242  34.9814  3016.578     2
# 2       Berkshire Hathaway       409.908  222.935  24.0740   620.854     3
# 3           JPMorgan Chase       306.616  102.494  24.2310  2512.986     4
# 4              Wells Fargo       274.385   97.573  21.9380  1943.443     5
#
#        Sector             Industry      Continent        Country Headquarters  \
# 0  Financials          Major Banks           Asia          China        China
# 1  Financials          Major Banks           Asia          China        China
# 2  Financials  Investment Services  North America  United States     Nebraska
# 3  Financials          Major Banks  North America  United States     New York
# 4  Financials          Major Banks  North America  United States   California
#
#         State                    CEO  \
# ...

# %%
# The path to our CSV file to extract 2018 Forbes_Global_2000 company list
Forbes_2018_csv = "Resources/Forbes_Global_2000_2018.csv"
Forbes_2018_df = pd.read_csv(Forbes_2018_csv)
Forbes_2018_df.head()
# Out:
#                       Company  Market Value  Revenue  Profits    Assets  Rank  \
# 0                        ICBC       311.014  165.338  43.6694  4210.927   1.0
# 1     China Construction Bank       261.166  143.202  37.2031  3631.583   2.0
# 2              JPMorgan Chase       387.668  118.180  26.4960  2609.785   3.0
# 3          Berkshire Hathaway       491.888  235.165  39.7420   702.651   4.0
# 4  Agricultural Bank of China       184.125  129.345  29.6387  3439.314   5.0
#
#        Sector             Industry      Continent        Country Headquarters  \
# 0  Financials          Major Banks           Asia          China        China
# 1  Financials          Major Banks           Asia          China        China
# 2  Financials          Major Banks  North America  United States     New York
# 3  Financials  Investment Services  North America  United States     Nebraska
# 4  Financials       Regional Banks           Asia          China        China
#
# ...

# %%
# The path to our CSV file to extract 2019 Forbes_Global_2000 company list
Forbes_2019_csv = "Resources/Forbes_Global_2000_2019.csv"
Forbes_2019_df = pd.read_csv(Forbes_2019_csv)
Forbes_2019_df.head()
# Out:
#                       Company  Market Value  Revenue  Profits    Assets  Rank  \
# 0                        ICBC       305.057  175.874   45.223  4034.482     1
# 1              JPMorgan Chase       368.502  132.912   32.738  2737.188     2
# 2     China Construction Bank       224.988  150.313   38.841  3382.422     3
# 3  Agricultural Bank of China       197.045  137.456   30.894  3293.105     4
# 4             Bank of America       287.339  111.904   28.540  2377.164     5
#
#        Sector        Industry      Continent        Country    Headquarters  \
# 0  Financials     Major Banks           Asia          China           China
# 1  Financials     Major Banks  North America  United States        New York
# 2  Financials     Major Banks           Asia          China           China
# 3  Financials  Regional Banks           Asia          China           China
# 4  Financials     Major Banks  North America  United States  North Carolina
#
#             State             CEO  \
# ...

# %% [markdown]
# # Extract: Inc 5000

# %%
# The path to our CSV file to extract 2017 Inc 5000 company list
Inc_2017_csv = "Resources/inc5000-2017.csv"
Inc_2017_df = pd.read_csv(Inc_2017_csv)
Inc_2017_df.head()
# Out:
#    year  rank               name                 url founded  \
# 0  2017  1350  Criterion Systems   criterion-sys.com  1/1/05
# 1  2017  1819  ITA INternational        ita-intl.com  1/1/05
# 2  2017  3712       ReSource Pro     resourcepro.com  1/1/03
# 3  2017  4182        Lifematters  lifemattersusa.com  1/1/04
# 4  2017  4700            Celergo         celergo.com  1/1/04
#
#                              street1           city state    zip  \
# 0         8330 Boone Blvd. Suite 400         Vienna    VA  22182
# 1      112 Cybernetics Way Suite 112       Yorktown    VA  23693
# 2  1180 AVENUE OF THE AMERICAS FL 16  New York City    NY  10036
# 3              8757 Georgia Ave #600  Silver Spring    MD  20910
# 4         750 Estate Drive Suite 110      Deerfield    IL  60015
#
#         revenue  % growth  Headcount                      Industry  \
# 0  48.6 million       302        233           Government Services
# 1  33.9 million       212        291           Government Services
# ...

# %%
# The path to our CSV file to extract 2018 Inc 5000 company list
Inc_2018_csv = "Resources/inc5000-2018.csv"
Inc_2018_df = pd.read_csv(Inc_2018_csv)
Inc_2018_df.head()
# Out:
#     _ - id          _ - url  _ - rank    _ - city  _ - ifmid  _ - ifiid  \
# 0  71021.0         swanleap       1.0     Madison       78.0        6.0
# 1  87397.0       popsockets       2.0     Boulder       31.0        4.0
# 2  87398.0        home-chef       3.0     Chicago       17.0       11.0
# 3  81957.0  velocity-global       4.0      Denver       30.0       17.0
# 4  87399.0     depcom-power       5.0  Scottsdale       46.0       16.0
#
#    _ - growth  _ - workers      _ - company                _ - website  ...  \
# 0  75660.8425         49.0         SwanLeap        http://swanleap.com  ...
# 1  71423.7620        118.0       PopSockets      http://popsockets.com  ...
# 2  60165.5058        865.0        Home Chef               homechef.com  ...
# 3  39816.5093         55.0  Velocity Global  http://velocityglobal.com  ...
# 4  38962.9022        104.0     DEPCOM Power            depcompower.com  ...
#
#   _ - zipcode _ - founded                  _ - industry  _ - latitude  \
# ...

# %%
# The path to our CSV file to extract 2019 Inc 5000 company list
Inc_2019_csv = "Resources/inc5000-2019.csv"
Inc_2019_df = pd.read_csv(Inc_2019_csv)
Inc_2019_df.head()
# Out:
#    _ - rank                                   Profile               name  \
# 0         1      https://www.inc.com/profile/freestar           Freestar
# 1         2   https://www.inc.com/profile/freightwise        FreightWise
# 2         3  https://www.inc.com/profile/ceces-veggie  Cece's Veggie Co.
# 3         4      https://www.inc.com/profile/ladyboss           LadyBoss
# 4         5        https://www.inc.com/profile/perpay             Perpay
#
#                          url state   _ - revenue  _ - growth  \
# 0        http://freestar.com    AZ  36.9 Million  36680.3882
# 1  http://freightwisellc.com    TN  33.6 Million  30547.9317
# 2   http://cecesveggieco.com    TX  24.9 Million  23880.4852
# 3        http://ladyboss.com    NM  32.4 Million  21849.8925
# 4          http://perpay.com    PA  22.5 Million  18166.4070
#
#                    _ - industry  _ - workers  _ - founded  _ - yrs_on_list  \
# 0       Advertising & Marketing         40.0         2015                1
# ...
